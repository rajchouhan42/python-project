# %% [markdown]
# #### Calculator scientific

# %%
## Addition

num1 = float(input("Enter a first  number here x:"))
num2 = float(input("Enter a second number here y:"))
ad = (num1+num2)
print("the addition of given number is ",ad)

## subtraction 

num1 = float(input("Enter a first number here x:"))
num2 = float(input("Enter a second number here y:"))
sb = (num1-num2)
print("the subtraction of given number is ",sb)

## Multiplication

num1 = float(input("Enter a first number here x:"))
num2 = float(input("Enter a second number here y:"))
mlt = (num1*num2)
print("the multiplication of given number is ",mlt)

## Division

num1 = float(input("Enter a first number here x:"))
num2 = float(input("Enter a second number here y:"))
dvd = (num1/num2)
print("the divition of given number is ",dvd)

# square root 
num1 = int(input("Enter a number here :"))
sr = num1**(0.5)             #square root (0.5 , 1/2)
print ("the square root of the given number is ",sr)

## square

num = float(input("Enter the number here :"))
sr1 = num**2
print("The square number is",sr1)

##cube
num = float(input("enter the number here :"))
cube = num**3
print("The cube number is ",cube)

#x^y
x = float(input("Enter the number here x:"))
y = float(input("Enter the number here y:"))
n1 = x ** y
print("The x^y number is ",n1)

# Modules

x = float(input("Enter the number here x :"))
y = float(input("Enter the number here y :"))
n1 = x % y
print("The x%y number is ",n1)

# 1/X

x = float(input("Enter the number here x :"))
num = 1/x
print("The 1/x number is ",num)

# log X
import math
x = float(input("enter the number here x:"))
num = log (x)
print("the log x number is ",)

# %% [markdown]
# ### Machine Learning

# %%
# Machine Learing
#import necessary libraies
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\\python\\Medicalpremium_nan.csv') #load data set
df.sample(10) #look the 10 random rows
# Out:
#       Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 874  51.0         1                    1.0               0
# 63   31.0         0                    0.0               0
# 535  46.0         0                    0.0               0
# 730  39.0         0                    0.0               0
# 741  19.0         0                    0.0               0
# 393  58.0         1                    1.0               0
# 368  35.0         0                    1.0               0
# 846  35.0         0                    1.0               0
# 284  50.0         0                    1.0               0
# 86   46.0         0                    1.0               1
#
#      AnyChronicDiseases  Height  Weight  KnownAllergies  \
# 874                   0     152      72               0
# 63                    1     163      78               0
# 535                   0     169      94               0
# 730                   0     172      92               0
# ...

# %%
# premium price on basis of given features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      975 non-null    float64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    974 non-null    float64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: float64(2), int64(9)
# memory usage: 84.9 KB

# %%
# check the null values 
df.isnull().sum()
# Out:
# Age                        11
# Diabetes                    0
# BloodPressureProblems      12
# AnyTransplants              0
# AnyChronicDiseases          0
# Height                      0
# Weight                      0
# KnownAllergies              0
# HistoryOfCancerInFamily     0
# NumberOfMajorSurgeries      0
# PremiumPrice                0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(41.74974358974359)

# %%
df['BloodPressureProblems'].mean()
# Out:
# np.float64(0.47125256673511295)

# %%
df['BloodPressureProblems'].value_counts()
# Out:
# BloodPressureProblems
# 0.0    515
# 1.0    459
# Name: count, dtype: int64

# %%
df = df.fillna({'Age':42,'BloodPressureProblems':0})
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
df.corr()
# Out:
#                               Age  Diabetes  BloodPressureProblems  \
# Age                      1.000000  0.210919               0.242655
# Diabetes                 0.210919  1.000000               0.128848
# BloodPressureProblems    0.242655  0.128848               1.000000
# AnyTransplants          -0.008673 -0.036652              -0.031925
# AnyChronicDiseases       0.051400 -0.089428               0.043019
# Height                   0.039928 -0.003783              -0.035011
# Weight                  -0.018742 -0.024563              -0.060349
# KnownAllergies          -0.024682 -0.080102              -0.013311
# HistoryOfCancerInFamily -0.027809 -0.055527               0.050485
# NumberOfMajorSurgeries   0.428829  0.122722               0.248959
# PremiumPrice             0.697682  0.076209               0.168795
#
#                          AnyTransplants  AnyChronicDiseases    Height  \
# Age                           -0.008673            0.051400  0.039928
# ...

# %%
sns.heatmap(df.corr(),annot = True, fmt = '0.2f',cmap = 'Blues')
# Out:
# <Axes: >

# %%
#filter the correlation with premium price only
sns.heatmap(df.corr()[['PremiumPrice']].sort_values(by = "PremiumPrice",ascending = False), annot = True , fmt ='0.2f',cmap ='Reds')
# Out:
# <Axes: >

# %%
plt.scatter(df['Age'],df['PremiumPrice'])

# %%
plt.scatter(df['Height'],df['PremiumPrice'])

# %%
plt.scatter(df['Weight'],df['PremiumPrice'])

# %%
df.boxplot('Age')
# Out:
# <Axes: >

# %%
df.boxplot('Weight')
# Out:
# <Axes: >

# %%
# Divide the data into independent and dependent data
y = df["PremiumPrice"]
y.head()
# Out:
# 0    25000
# 1    29000
# 2    23000
# 3    28000
# 4    23000
# Name: PremiumPrice, dtype: int64

# %% [markdown]
# x = df.drop('PremiumPrice', axis = 1)
# x

# %%
#split the data into train and test
# Now split the data into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2, random_state=5)

# %%
#Now check the shape of split data 
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (788, 10) (198, 10)
# (788,) (198,)

# %% [markdown]
# ### import the linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
# Creation of object of model
lr_model = LinearRegression()

# %%
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_model.coef_
# Out:
# array([ 3.23789181e+02, -5.24557808e+02,  3.16954400e+02,  8.64685296e+03,
#         2.59509424e+03, -4.51489899e+00,  7.36658360e+01,  1.99730901e+02,
#         2.40559230e+03, -6.49123720e+02])

# %%
lr_model.intercept_
# Out:
# np.float64(5275.237639152514)

# %%
y_pred = lr_model.predict(x_test)
y_pred
# Out:
# array([26710.48525463, 22860.64254933, 27249.17425056, 21063.51843627,
#        17803.2736817 , 18592.51640065, 22964.98858906, 19641.69746696,
#        20889.66565498, 28235.5394672 , 29226.21466591, 26307.40525315,
#        30607.17528714, 30498.18868809, 27648.26126223, 29936.88776185,
#        23937.81751121, 19941.78452026, 26483.51061739, 38648.99924266,
#        16146.48131396, 22037.49380858, 24752.68089402, 24889.5651627 ,
#        31415.31922756, 29481.44022324, 23409.05397554, 26996.65912346,
#        28838.11616478, 28867.52427423, 30397.56485647, 18913.57637613,
#        21006.7404265 , 27589.98513351, 21283.1255165 , 24409.24753489,
#        17137.12643328, 25723.81240983, 28200.23037709, 37254.41393628,
#        19481.05546631, 15748.50765509, 21599.84671439, 21709.91662568,
#        22615.43855145, 19546.67694309, 23466.9043035 , 18884.66492891,
#        29466.5363001 , 27488.39833159, 24586.34825977, 29189.32032864,
# ...

# %%
x_test
# Out:
#       Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 935  38.0         0                    1.0               0
# 176  42.0         0                    0.0               0
# 629  42.0         0                    0.0               0
# 739  25.0         0                    1.0               0
# 300  26.0         1                    0.0               0
# ..    ...       ...                    ...             ...
# 203  24.0         0                    1.0               0
# 477  49.0         1                    1.0               0
# 479  45.0         1                    0.0               0
# 399  43.0         0                    0.0               0
# 758  46.0         1                    1.0               0
#
#      AnyChronicDiseases  Height  Weight  KnownAllergies  \
# 935                   1     170      71               0
# 176                   0     176      71               1
# 629                   1     172      89               0
# ...

# %%
df.loc[300]
# Out:
# Age                           26.0
# Diabetes                       1.0
# BloodPressureProblems          0.0
# AnyTransplants                 0.0
# AnyChronicDiseases             0.0
# Height                       181.0
# Weight                        74.0
# KnownAllergies                 0.0
# HistoryOfCancerInFamily        0.0
# NumberOfMajorSurgeries         0.0
# PremiumPrice               15000.0
# Name: 300, dtype: float64

# %%
y_pred[:10]
# Out:
# array([26710.48525463, 22860.64254933, 27249.17425056, 21063.51843627,
#        17803.2736817 , 18592.51640065, 22964.98858906, 19641.69746696,
#        20889.66565498, 28235.5394672 ])

# %%
(abs(y_test-y_pred)).mean() # MAE
# Out:
# np.float64(2579.206830828225)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error,root_mean_squared_error

# %%
def model_eve(model_name,y_test,y_pred):
    print(f'{model_name} R2_score',r2_score(y_test,y_pred))
    print(f'{model_name} , MAE',mean_absolute_error(y_test,y_pred))
    print(f'{model_name},MSE',mean_squared_error(y_test,y_pred))
    print(f'{model_name},RMSE',root_mean_squared_error(y_test,y_pred))

# %%
model_eve('lr_model',y_test,y_pred)
# Out:
# lr_model R2_score 0.6794608496489137
# lr_model , MAE 2579.206830828225
# lr_model,MSE 11233072.29534995
# lr_model,RMSE 3351.577583071881

# %%
######## Change in random state ########
# split the into train and test 
# Now split the data into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
# Creation of object of model
lr_model4 = LinearRegression()

# %%
lr_model4.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model4.coef_
# Out:
# array([ 317.58864538, -415.60432858,  382.40889514, 7581.31628671,
#        2564.34738875,  -10.49820843,   68.76591707,   79.98403342,
#        2403.60829271, -609.0053617 ])

# %%
y_pred4 = lr_model.predict(x_test)
y_pred4
# Out:
# array([19718.55806735, 22306.72957939, 19283.21344399, 24815.13646941,
#        30993.88634431, 27564.49948113, 15557.15462571, 25748.02426998,
#        19609.14712705, 28355.37059569, 23386.63805511, 37679.16356692,
#        25027.22391198, 31953.73252221, 28584.55697864, 25859.70632158,
#        34769.95711039, 27791.78230287, 27217.49946374, 28936.92630303,
#        28328.85605796, 16832.21531017, 20474.36195778, 26031.28741942,
#        14819.67780367, 17689.93258427, 25773.07904726, 29799.40111671,
#        25092.09862696, 26875.72118091, 19451.04560262, 29481.44022324,
#        27455.28405199, 35337.48527119, 20186.40935339, 26206.68739028,
#        20018.40355366, 27207.31361199, 22027.81435196, 26331.11061343,
#        14828.09861114, 31116.71766674, 31939.59198263, 20463.50563006,
#        18480.28705077, 27284.44698106, 24636.95495922, 16341.32397014,
#        28949.20911806, 16034.09826525, 27367.56344362, 35196.27881234,
# ...

# %%
model_eve('lr_model4', y_test, y_pred4)
# Out:
# lr_model4 R2_score 0.7911702398519331
# lr_model4 , MAE 2355.9234246012793
# lr_model4,MSE 9021958.07138614
# lr_model4,RMSE 3003.6574490754

# %%
######### use of model ##########
lr_model4.predict([[55,1,1,1,0,160,169,1,0,1]])
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41184.82172459])

# %%
df.loc[5]
# Out:
# Age                           30.0
# Diabetes                       0.0
# BloodPressureProblems          0.0
# AnyTransplants                 0.0
# AnyChronicDiseases             0.0
# Height                       160.0
# Weight                        69.0
# KnownAllergies                 1.0
# HistoryOfCancerInFamily        0.0
# NumberOfMajorSurgeries         1.0
# PremiumPrice               23000.0
# Name: 5, dtype: float64

# %%
## NEW DATASET



df = pd.read_csv('paris.csv')

# %%
df
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %%
plt.scatter(df['squareMeters'], df['price'])

# %%
plt.figure(figsize = (10,6))
sns.heatmap(df.corr(), annot= True, fmt = '.2f', cmap = 'Reds')
# Out:
# <Axes: >

# %%
# Filter the correlation with premium price only
sns.heatmap(df.corr()[['price']].sort_values(by = "price", ascending = False), annot = True, fmt = '0.2f' , cmap ='Reds')
# Out:
# <Axes: >

# %% [markdown]
# ### NEW DATASET- MEDICALPREMIUM

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Medicalpremium_nan.csv')
df.describe().T
# Out:
#                          count          mean          std      min      25%  \
# Age                      975.0     41.749744    14.041846     18.0     30.0
# Diabetes                 986.0      0.419878     0.493789      0.0      0.0
# BloodPressureProblems    974.0      0.471253     0.499429      0.0      0.0
# AnyTransplants           986.0      0.055781     0.229615      0.0      0.0
# AnyChronicDiseases       986.0      0.180527     0.384821      0.0      0.0
# Height                   986.0    168.182556    10.098155    145.0    161.0
# Weight                   986.0     76.950304    14.265096     51.0     67.0
# KnownAllergies           986.0      0.215010     0.411038      0.0      0.0
# HistoryOfCancerInFamily  986.0      0.117647     0.322353      0.0      0.0
# NumberOfMajorSurgeries   986.0      0.667343     0.749205      0.0      0.0
# PremiumPrice             986.0  24336.713996  6248.184382  15000.0  21000.0
#
#                              50%      75%      max
# ...

# %%
df.boxplot('Weight')
plt.show()

# %%
df=df[df['Weight']<117]

# %%
import seaborn as sns
sns.boxplot(df['Weight'])
# Out:
# <Axes: ylabel='Weight'>

# %%
df.describe().T
# Out:
#                          count          mean          std      min      25%  \
# Age                      959.0     41.813347    13.987080     18.0     30.0
# Diabetes                 970.0      0.423711     0.494401      0.0      0.0
# BloodPressureProblems    958.0      0.471816     0.499466      0.0      0.0
# AnyTransplants           970.0      0.055670     0.229402      0.0      0.0
# AnyChronicDiseases       970.0      0.182474     0.386434      0.0      0.0
# Height                   970.0    168.202062    10.130745    145.0    161.0
# Weight                   970.0     76.182474    13.045791     51.0     67.0
# KnownAllergies           970.0      0.214433     0.410640      0.0      0.0
# HistoryOfCancerInFamily  970.0      0.116495     0.320983      0.0      0.0
# NumberOfMajorSurgeries   970.0      0.667010     0.750263      0.0      0.0
# PremiumPrice             970.0  24325.773196  6206.213444  15000.0  21000.0
#
#                              50%      75%      max
# ...
